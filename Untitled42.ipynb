# %% [markdown]
# <a href="https://colab.research.google.com/github/nyantata/colab_test/blob/main/Untitled42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time

sleep_time = 10

print("Hello")
for i in range(sleep_time):
  print("■",end="")
  time.sleep(1)


print("")
print("end")
# Out:
# Hello
# ■■■■■■■■■■
# end
